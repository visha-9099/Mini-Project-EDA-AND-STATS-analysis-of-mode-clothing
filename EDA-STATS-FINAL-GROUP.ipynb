# %% [markdown]
# # PROJECT 4 - EDA AND STATS

# %% [markdown]
#  MOD CLOTHING CASE STUDY

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px
from scipy.stats import trim_mean
from sklearn.preprocessing import StandardScaler
import statistics as st
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats import weightstats
import statistics
import random
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Part A

# %% [markdown]
# The following data represents the price in dollars for branded shirts in a website
# NuCloth.
#
#
# 23 30 20 27 44 26 35 20 29 29
#
# 25 15 18 27 19 22 12 26 34 15
#
# 27 35 26 43 35 14 24 12 23 31
#
# 40 35 38 57 22 42 24 21 27 33
#
# Use this data for answering following questions where relevant

# %% [markdown]
# Q1. Compute the mean, median and the mode of the data

# %%
data=np.array([23,30,20,27,44,26,35,20,29,29,
               25,15,18,27,19,22,12,26,34,15,
               27,35,26,43,35,14,24,12,23,31,
               40,35,38,57,22,42,24,21,27,33])
print('Mean of the Price is :', np.mean(data))
print('Median of the Price is :', np.median(data))
print('Mode of the Price is :', st.mode(data))
# Out:
# Mean of the Price is : 27.625
# Median of the Price is : 26.5
# Mode of the Price is : 27

# %% [markdown]
#  Q2. Compute the range , variance and standard deviation of the data

# %%
print('Range of the Price is :', max(data)-min(data))
print('variance of the Price is :', np.var(data))
print('Standard Deviation of the Price is :', np.std(data))
# Out:
# Range of the Price is : 45
# variance of the Price is : 90.284375
# Standard Deviation of the Price is : 9.501809038283184

# %% [markdown]
# Q3. Find the mean deviation for the data . The mean deviation is defined as below.

# %%
x_bar = np.mean(data)
x_bar
for x in data:
    mu=x-x_bar/len(data)
print('Mean Deviation of Price is : ',mu)
# Out:
# Mean Deviation of Price is :  32.309375

# %% [markdown]
# Q4. Calculate the Pearson coefficient of skewness and comment on the skewness of the data [A measure to determine the skewness of a distribution is called the Pearson coefficient of skewness. Formula = 3*(mean-median)/sd

# %%
mean = np.mean(data)
median = np.median(data)
sd= np.std(data) 
print('Pearson coefficient of skewness of Price is ',3*((mean-median)/sd))
# the distribution is positively skewed and moderately skewed since it lies between 0.5 and 1.
# Out:
# Pearson coefficient of skewness of Price is  0.35519551975860436

# %% [markdown]
# Coefficient of skewness is 0.3 Hence, Data is symmetrically distributed

# %% [markdown]
# Q5. Count the number of data values that fall within two standard deviations of the mean. Compare this with the answer from Chebyshev’s Theorem

# %%
from scipy.stats import zscore
z_score=zscore(data)
z_score
len(z_score[(z_score>-2)&(z_score<2)])
# Chebyshev's theorem
# Out:
# 39

# %% [markdown]
# 39 values fall within two standard deviations of the mean.

# %% [markdown]
# Q6. Find the three quartiles and the interquartile range (IQR).

# %%
print('First Quartile range is :',np.quantile(data,0.25))
print('Second Quartile range is :',np.quantile(data,0.50))
print('Third Quartile range is :',np.quantile(data,0.75))
# Out:
# First Quartile range is : 21.75
# Second Quartile range is : 26.5
# Third Quartile range is : 34.25

# %%
Q1=np.quantile(data,0.25)
Q3=np.quantile(data,0.75)
print('IQR is :',Q3-Q1)
# Out:
# IQR is : 12.5

# %% [markdown]
# Q7. Are there any outliers in the data set ?

# %%
z_score[(z_score>3)|(z_score<-3)]
# Out:
# array([3.09151656])

# %%
len(z_score[(z_score>3)|(z_score<-3)])
# Out:
# 1

# %% [markdown]
# Yes there is 1 outlier in data

# %% [markdown]
# Q8. Draw a boxplot of the dataset to confirm.

# %%
sns.boxplot(data,color='red')
plt.show()

# %% [markdown]
# Boxplot confirms there is 1 outlier in data

# %% [markdown]
# Q9. Find the percentile rank of the datapoint 25.

# %%
dataframe=pd.DataFrame(data)
pr=stats.percentileofscore(a=data,score=25,kind='rank')
print('The percentile rank of the datapoint 25 is',pr)
# Out:
# The percentile rank of the datapoint 25 is 42.5

# %% [markdown]
# Q10. What is the probability that a shirt cost is above 25 dollars?

# %%
stats.norm.sf(25.0,mean,sd)
# Out:
# 0.608827033824017

# %% [markdown]
# Probability of shirt cost above 25 dollars is 0.608827033824017

# %% [markdown]
# Q11. Create a frequency distribution for the data and visualize it appropriately

# %%
sns.countplot(data)
plt.show()

# %% [markdown]
# Q12. Create a probability distribution of the data and visualize it appropriately.

# %%
sns.kdeplot(data)
plt.show()

# %% [markdown]
# Q13. What is the shape of the distribution of this dataset? Create an appropriate graph to determine that. Take 100 random samples with replacement from this dataset of size 5 each. Create a sampling distribution of the mean shirt prices. Compare with other sampling distributions of sample size 10, 15, 20, 25, 30. State your observations. Does it corroborate the Central Limit Theorem?

# %%
# Sampling distribution of sample size 5
l1=[]
for i in range(1,101):
    sample1=random.choices(data,k=5)
    l1.append(np.mean(sample1))
sns.histplot(l1,kde=True)
plt.show()

# %%
# Sampling distribution of sample size 10
l2=[]
for i in range(1,101):
    sample2=random.choices(data,k=10)
    l2.append(np.mean(sample2))
sns.histplot(l2,kde=True)
plt.show()

# %%
# Sampling distribution of sample size 15
l3=[]
for i in range(1,101):
    sample3=random.choices(data,k=15)
    l3.append(np.mean(sample3))
sns.histplot(l3,kde=True)
plt.show()

# %%
# Sampling distribution of sample size 20
l4=[]
for i in range(1,101):
    sample4=random.choices(data,k=20)
    l4.append(np.mean(sample4))
sns.histplot(l4,kde=True)
plt.show()

# %%
# Sampling distribution of sample size 25
l5=[]
for i in range(1,101):
    sample5=random.choices(data,k=25)
    l5.append(np.mean(sample5))
sns.histplot(l5,kde=True)
plt.show()

# %%
# Sampling distribution of sample size 30
l6=[]
for i in range(1,101):
    sample6=random.choices(data,k=30)
    l6.append(np.mean(sample6))
sns.histplot(l6,kde=True)
plt.show()

# %% [markdown]
# The sampling distribution of the mean is always normally distributed. Therfore it follows the Central Limit Theorem

# %% [markdown]
# Q14. Treat this dataset as a binomial distribution where p is the probability that a shirt costs above 25 dollars. What is the probability that out of a random sample of 10 shirts 7 are costing more than 25 dollars?

# %%
n=10
x=7
total=len(data)
observed=len(data[data>=25])
p=observed/total
print('Probability that out of a random sample of 10 shirts 7 are costing more than 25 dollars is',stats.binom.pmf(x,n,p))
# Out:
# Probability that out of a random sample of 10 shirts 7 are costing more than 25 dollars is 0.21499084799999976

# %% [markdown]
# Q15. NuCloth Claims that 60% of all shirts in their website cost less than 25
# dollars . Using the Normal approximation of a Binomial distribution, find the probability that in a random sample of 10 shirts 7 of them will cost less than 25 dollars.
# [ Note that the normal distribution can be used to approximate a binomial
# distribution if np>=5 and nq>=5 with the following correction for continuity
# P(X=z) = P(z-0.5 < X < z+0.5 ) ]

# %%
p=0.6
n=10
x=7
print('Probability that in a random sample of 10 shirts 7 of them will cost less than 25 dollars is ',stats.binom.pmf(x,n,p))
# Out:
# Probability that in a random sample of 10 shirts 7 of them will cost less than 25 dollars is  0.21499084799999976

# %% [markdown]
# Q16. Compute a 95% Confidence Interval for the true price of a shirt in the NuCloth website using appropriate distribution.
# (State reasons as to why did you use a z or t distribution)

# %%
#Here t distribution will be used because the population standard deviation is not known.

# %%
std=np.std(data,ddof=1)
std
n=len(data)
n
mean
# Out:
# 27.625

# %%
stats.t.interval(0.95,loc=mean,scale=(std/n**0.5),df=n-1)
# Out:
# (24.547461337585172, 30.702538662414828)

# %% [markdown]
# Q17. A data scientist wants to estimate with 95% confidence the true proportion of shirts having price greater than 25 dollars in the NuCloth website. A recent study showed that 60% of all shirts have a price greater than 25 dollars. The data scientist wants to be accurate within 2% of the true proportion. Find the minimum sample size necessary.

# %%
p_pop=0.6
q_pop=1-0.6
alpha=0.05
z_alpha_by_2=stats.norm.sf(alpha/2)
E=0.02
# E is the margin of error
n=(p_pop*q_pop)*((z_alpha_by_2)/(E))**2
output=np.ceil(n)
print('Minimum sample size required for this analysis is: ',output)
# Out:
# Minimum sample size required for this analysis is:  145.0

# %% [markdown]
# Q18. The same data scientist wants to estimate the true proportion of shirts having price greater than 25 dollars. She wants to be 90% confident and accurate within 5% of true proportion. Find the minimum sample size necessary.

# %%
total=len(data)
observed=len(data[data>=25])
p_pop=observed/total
q_pop=1-p_pop
alpha=0.1
E=0.05
z_alpha_by_2=stats.norm.sf(alpha/2)
n=(p_pop*q_pop)*((z_alpha_by_2)/(E))**2
output=np.ceil(n)
print('Minimum sample size required for this analysis is: ',output)
# Out:
# Minimum sample size required for this analysis is:  23.0

# %% [markdown]
# # Q19. NuCloth claims that currently 80% of all shirts have prices greater than 25 dollars . Test this claim with an alpha =0.05 if out of a random sample of 30 shirts only 23 are having prices above 25 dollars.

# %% [raw]
# H0:P<=0.8
# H1:P>0.8

# %%
alpha=0.05
n=30
x=23
p_samp=x/n
hypo_p=0.8

# %%
z_stat=(p_samp-hypo_p)/np.sqrt((hypo_p*(1-hypo_p))/n)
z_stat
# Out:
# -0.45643546458763834

# %%
p_value=stats.norm.sf(z_stat)
p_value
# Out:
# 0.6759615659304269

# %% [markdown]
# Since pvalue is greater than 0.05 we fail to reject H0. Therefore there is no enough evidence to say that 80% of all shirts have prices greater than 25 dollars.

# %% [markdown]
# Q20. A data scientist is researching the hypothesis that the average price of a shirt in NuCloth is higher than the supermarket. So he collects data from NuCloth and the supermarket that the average shirt price of shirts in NuCloth is 36 dollars vs 34
# dollars in the supermarket. The standard deviations are 7.6 and 5.8 respectively.Suppose the data scientist got these values after randomly selecting 100 shirts from each place.
# a. What hypothesis would he use to compare the shirt prices of NuCloth vsSupermarket
# b. What are critical values to be used?
# c. What statistical test will be used to compare these prices?
# d. Complete the test and obtain the P-value.
# e. Summarize his conclusion based on the P-value.

# %% [markdown]
# A. What hypothesis would he use to compare the shirt prices of NuCloth vsSupermarket

# %% [raw]
# H0:u1<=u2
# H1:u1>u2
# u1: Average shirt price of NuCloth
# u1: Average shirt price of supermarket

# %%
x1_bar=36
x2_bar=34
s1=7.6
s2=5.8
n1=100
n2=100
null_value=0
# degrees of freedom for 2 sample t-test
print('Degrees of freedom:', n1 + n2 - 2)
# Out:
# Degrees of freedom: 198

# %% [markdown]
# B. What are critical values to be used?

# %%
alpha=0.05
z_critical=stats.norm.isf(alpha)
print('Critical values to be used is',z_critical)
# Out:
# Critical values to be used is 1.6448536269514729

# %% [markdown]
# C. What statistical test will be used to compare these prices?

# %% [markdown]
# Two Sample T-test will be used to compare the means of these prices

# %% [markdown]
# D.Complete the test and obtain the P-value.

# %%
# calculate pooled standard deviation
s = np.sqrt((((n1-1)*s1**2) + ((n2-1)*s2**2)) / (n1 + n2 - 2))
t_stat = (x1_bar - x2_bar) / (s * np.sqrt(1/n1 + 1/n2))
p_value=stats.t.sf(t_stat,df = n1 + n2 - 2)
print('Test Statistic:', t_stat,'P-value',p_value)
# Out:
# Test Statistic: 2.0919769632765197 P-value 0.01885775783786387

# %% [markdown]
# E. Summarize his conclusion based on the P-value.
#
#
# Since pvalue is lesser than 0.05 we reject H0. Therfore average shirt price of NuCloth is greater than average shirt price of supermarket.

# %% [markdown]
# # PART B

# %% [markdown]
# 1. Read the datasets, Check the data types and Change the data types appropriately

# %%
df1=pd.read_json('modcloth_final_data.json',lines=True)
df1.head(2)
# Out:
#    item_id  waist  size  quality cup size  hips  bra size category bust  \
# 0   123373   29.0     7      5.0        d  38.0      34.0      new   36
# 1   123373   31.0    13      3.0        b  30.0      36.0      new  NaN
#
#     height         user_name      length    fit  user_id  shoe size  \
# 0  5ft 6in             Emily  just right  small   991571        NaN
# 1  5ft 2in  sydneybraden2001  just right  small   587883        NaN
#
#   shoe width review_summary review_text
# 0        NaN            NaN         NaN
# 1        NaN            NaN         NaN

# %%
df2=df1

# %%
df2.dtypes
# Out:
# item_id             int64
# waist             float64
# size                int64
# quality           float64
# cup size           object
# hips              float64
# bra size          float64
# category           object
# bust               object
# height             object
# user_name          object
# length             object
# fit                object
# user_id             int64
# shoe size         float64
# shoe width         object
# review_summary     object
# review_text        object
# dtype: object

# %% [markdown]
# 2. Change the height column datatype to float after converting the values as shown

# %%
df2['height']=df2['height'].str.replace('ft','')
df2['height']=df2['height'].str.replace('in','')
df2['height']=df2['height'].str.replace(' ','.')
df2['height'].astype(float)
# Out:
# 0        5.6
# 1        5.2
# 2        5.7
# 3        NaN
# 4        5.2
#         ...
# 82785    5.8
# 82786    5.5
# 82787    5.4
# 82788    5.3
# 82789    6.0
# Name: height, Length: 82790, dtype: float64

# %% [markdown]
# 3. Rename the names of the columns which have space in between the column.
# Ex: shoe size as shoe_size etc.

# %%
df2.columns = df2.columns.str.replace(' ', '_')

# %%
df2.columns
# Out:
# Index(['item_id', 'waist', 'size', 'quality', 'cup_size', 'hips', 'bra_size',
#        'category', 'bust', 'height', 'user_name', 'length', 'fit', 'user_id',
#        'shoe_size', 'shoe_width', 'review_summary', 'review_text'],
#       dtype='object')

# %% [markdown]
# 4. Check the missing values and Identify the distribution of the variables to impute the missing values. Explain based on your analysis decide the features which can be dropped and Which can be imputed. And also explain the reason to choose the metric that you have chosen to impute the null values.

# %% [markdown]
# 4.1 Check the count and percentage of missing values

# %%
print(df2.isnull().sum()/len(df2)*100)
# Count of null values
print(df2.isnull().sum().sum())
# Out:
# item_id            0.000000
# waist             96.518903
# size               0.000000
# quality            0.082136
# cup_size           7.555260
# hips              32.281677
# bra_size           7.268994
# category           0.000000
# bust              85.681846
# height             1.337118
# user_name          0.000000
# length             0.042276
# fit                0.000000
# user_id            0.000000
# shoe_size         66.282160
# shoe_width        77.525063
# review_summary     8.122962
# review_text        8.122962
# dtype: float64
# 323561

# %% [markdown]
# 4.2 check the Mean and Median

# %%
df2.mean()
# Out:
# item_id      469325.229170
# waist            31.319223
# size             12.661602
# quality           3.949058
# hips             40.358501
# bra_size         35.972125
# user_id      498849.564718
# shoe_size         8.145818
# dtype: float64

# %%
df2.median()
# Out:
# item_id      454030.0
# waist            30.0
# size             12.0
# quality           4.0
# hips             39.0
# bra_size         36.0
# height            5.5
# user_id      497913.5
# shoe_size         8.0
# dtype: float64

# %% [markdown]
# 4.3 Check the distribution of the variables using Histogram or Dist plot or KDE and boxplot etc. Kindly explore at least two.

# %%
sns.kdeplot(df2['bra_size'],color='red')
plt.show()

# %%
sns.boxplot(df2['bra_size'],color='yellow')
plt.show()

# %%
sns.kdeplot(df2['hips'],color='green')
plt.show()

# %%
sns.boxplot(df2['hips'],color='pink')
plt.show()

# %% [markdown]
# 4.4 Check the Skewness and Kurtosis. Explain what the Skewness and Kurtosis describe.

# %%
df2.skew()
# Out:
# item_id     -0.120644
# waist        0.993061
# size         1.128301
# quality     -0.676777
# hips         0.969187
# bra_size     0.901004
# height      -1.095275
# user_id      0.008201
# shoe_size    0.436713
# dtype: float64

# %%
df2.kurt()
# Out:
# item_id     -1.215909
# waist        0.836624
# size         0.760010
# quality     -0.167085
# hips         0.848464
# bra_size     1.039445
# height       5.311308
# user_id     -1.182436
# shoe_size    8.448820
# dtype: float64

# %% [markdown]
# Skewness is a measure of symmetry, or more precisely, the lack of symmetry.
# Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution.

# %% [markdown]
#  If the skewness is less than -1 or greater than 1, the data are highly skewed.
#
#  For example:Height column
#
#  If the kurtosis number is greater than +1, the distribution is too peaked.
#
#  For example: Height column

# %% [markdown]
#  4.5 Based on the above approach impute the missing values with the right metric.  Or If you want to get some analysis before imputing missing values feel free to explore the analysis

# %%
df3=df2

# %%
# Missing value imputation
df3.isnull().sum()/len(df3)*100
# Out:
# item_id            0.000000
# waist             96.518903
# size               0.000000
# quality            0.082136
# cup_size           7.555260
# hips              32.281677
# bra_size           7.268994
# category           0.000000
# bust              85.681846
# height             1.337118
# user_name          0.000000
# length             0.042276
# fit                0.000000
# user_id            0.000000
# shoe_size         66.282160
# shoe_width        77.525063
# review_summary     8.122962
# review_text        8.122962
# dtype: float64

# %%
df3=df3.drop(['bust','waist'],axis=1)

# %%
# Since the hips column was not symmetric we replaced the null values by the median of the column
df3['hips'].fillna(df3['hips'].median(),inplace=True)

# %%
df4=df3
df4.isnull().sum()/len(df4)*100
# Out:
# item_id            0.000000
# size               0.000000
# quality            0.082136
# cup_size           7.555260
# hips               0.000000
# bra_size           7.268994
# category           0.000000
# height             1.337118
# user_name          0.000000
# length             0.042276
# fit                0.000000
# user_id            0.000000
# shoe_size         66.282160
# shoe_width        77.525063
# review_summary     8.122962
# review_text        8.122962
# dtype: float64

# %%
df4.dropna(subset='quality',inplace=True)
df4.dropna(subset=(['cup_size','bra_size']),inplace=True)
df4.dropna(subset=(['height','length','review_summary']),inplace=True)

# %%
df4.isnull().sum()/len(df4)*100
# Out:
# item_id            0.000000
# size               0.000000
# quality            0.000000
# cup_size           0.000000
# hips               0.000000
# bra_size           0.000000
# category           0.000000
# height             0.000000
# user_name          0.000000
# length             0.000000
# fit                0.000000
# user_id            0.000000
# shoe_size         64.384982
# shoe_width        75.963823
# review_summary     0.000000
# review_text        0.000000
# dtype: float64

# %%
df4['shoe_width'].value_counts()
# Out:
# average    11798
# wide        3496
# narrow      1396
# Name: shoe_width, dtype: int64

# %%
df4['shoe_size'].fillna(df4['shoe_size'].mean(),inplace=True)
df4['shoe_width'].fillna('average',inplace=True)

# %%
df4.isnull().sum()/len(df4)*100
# Out:
# item_id           0.0
# size              0.0
# quality           0.0
# cup_size          0.0
# hips              0.0
# bra_size          0.0
# category          0.0
# height            0.0
# user_name         0.0
# length            0.0
# fit               0.0
# user_id           0.0
# shoe_size         0.0
# shoe_width        0.0
# review_summary    0.0
# review_text       0.0
# dtype: float64

# %% [markdown]
# The missing values have been imputed.

# %% [markdown]
# 5. Find the outliers which are below and above 2.5 * IQR - Q1 and 2.5 * IQR + Q3.

# %%
df4['height']=df4['height'].astype(float)

# %%
q1=df4['height'].quantile(0.25)
q2=df4['height'].quantile(0.5)
q3=df4['height'].quantile(0.75)
IQR=q3-q1
IQR
# Out:
# 0.40000000000000036

# %%
LL=(2.5*IQR-q1)
UL=(2.5*IQR+q3)

# %%
df4[(df4['height']<LL)|(df4['height']>UL)]
# Out:
#        item_id  size  quality cup_size  hips  bra_size   category  height  \
# 9080    161514    12      5.0        k  60.0      48.0    dresses    7.11
# 10369   163558     8      3.0     dd/e  60.0      48.0    dresses    7.11
# 11619   165525    26      3.0        k  60.0      48.0    dresses    7.11
# 19586   269063    13      4.0        k  60.0      48.0    dresses    7.11
# 29098   402677    12      5.0        k  60.0      48.0        new    7.11
# 29576   404229     8      5.0        b  39.0      38.0        new    6.80
# 35763   414247    12      3.0        b  39.0      32.0        new    7.50
# 37635   416942    12      5.0        k  60.0      48.0        new    7.11
# 38975   427041    12      5.0        k  60.0      48.0       tops    7.11
# 39588   427567    12      5.0        k  60.0      48.0       tops    7.11
# 41332   454030    12      5.0        k  60.0      48.0       tops    7.11
# 42130   454764    12      5.0        k  60.0      48.0       tops    7.11
# 44396   481011    12      3.0        k  60.0      48.0       tops    7.11
# 47348   515644    20      3.0        b  42.0      38.0       tops    6.80
# 51383   539980    12      5.0        k  60.0      48.0       tops    7.11
# 53327   604607    12      3.0        k  60.0      48.0       tops    7.11
# 54090   630114     4      3.0        a  39.0      34.0       tops    7.30
# 57726   647235    12      5.0        k  60.0      48.0       tops    7.11
# 57727   647235    12      5.0        k  60.0      48.0       tops    7.11
# 63119   661775    12      4.0        k  60.0      48.0        new    7.11
# 64250   668696    12      4.0        k  60.0      48.0    bottoms    7.11
# 64697   668696     4      5.0     dd/e  38.0      32.0    bottoms    7.70
# 71407   726492    15      3.0        k  60.0      48.0    bottoms    7.11
# 73583   754891    15      4.0        k  60.0      48.0    bottoms    7.11
# 75472   757242     4      5.0     dd/e  38.0      32.0    bottoms    7.70
# 77423   768741    15      5.0        k  60.0      48.0    bottoms    7.11
# 80344   792842    12      4.0        k  60.0      48.0  outerwear    7.11
# 80713   796383    12      4.0        k  60.0      48.0  outerwear    7.11
#
#           user_name          length    fit  user_id  shoe_size shoe_width  \
# 9080   bandnerd2522      just right    fit   708288  11.500000    average
# 10369     colmaggie      just right  small   618585   8.137262    average
# 11619  bandnerd2522      just right  small   810539  11.500000    average
# 19586  bandnerd2522      just right  small   708288  11.500000    average
# 29098  bandnerd2522      just right    fit   810539  11.500000    average
# 29576          C.J.      just right    fit   706293   8.137262    average
# 35763        lab262   slightly long    fit   393729   9.500000    average
# 37635  bandnerd2522      just right  small   708288  11.500000    average
# 38975  bandnerd2522      just right    fit   810539  11.500000    average
# 39588  bandnerd2522      just right  small   708288  11.500000    average
# 41332  bandnerd2522      just right    fit   810539  11.500000    average
# 42130  bandnerd2522      just right  small   708288  11.500000    average
# 44396  bandnerd2522      just right  small   810539  11.500000    average
# 47348        Lauren      just right    fit    10217   8.137262    average
# 51383  bandnerd2522      just right  small   708288  11.500000    average
# 53327  bandnerd2522      just right  small   708288  11.500000    average
# 54090         Samma      just right    fit   542270   8.137262    average
# 57726  bandnerd2522      just right    fit   810539  11.500000    average
# 57727  bandnerd2522      just right    fit   810539  11.500000    average
# 63119  bandnerd2522      just right  small   708288  11.500000    average
# 64250  bandnerd2522   slightly long    fit   708288  11.500000    average
# 64697     a.roodman       very long  large   945527   8.137262    average
# 71407  bandnerd2522  slightly short    fit   708288  11.500000    average
# 73583  bandnerd2522      just right  small   810539  11.500000    average
# 75472     a.roodman      just right    fit   945527   8.137262    average
# 77423  bandnerd2522      just right    fit   708288  11.500000    average
# 80344  bandnerd2522      just right  small   810539  11.500000    average
# 80713  bandnerd2522      just right  small   810539  11.500000    average
#
#                   review_summary  \
# 9080   I absolutely love this dr
# 10369  Love the dress. I feel it
# 11619   The dress looks like the
# 19586  This dress was beautiful,
# 29098  I LOVE THESE SHIRTS. They
# 29576  This is my new favorite s
# 35763  This top is perfect for m
# 37635  I love these cardigans. T
# 38975  I LOVE THESE SHIRTS. They
# 39588  I love these cardigans. T
# 41332  I LOVE THESE SHIRTS. They
# 42130  I love these cardigans. T
# 44396  I really love this shirt.
# 47348           Must have shirt!
# 51383  I love these cardigans. T
# 53327  I really love these sweat
# 54090                   Was okay
# 57726  I LOVE THESE SHIRTS. They
# 57727  I LOVE THESE SHIRTS. They
# 63119  The waist of this shirt w
# 64250  This skirt looks just lik
# 64697  I originally ordered a me
# 71407  The pattern is just as lo
# 73583  These were soft and the c
# 75472  This dress has become a c
# 77423   These are great leggings
# 80344  I need blazers to wear ov
# 80713  This jacket is lovely, bu
#
#                                              review_text
# 9080   I absolutely love this dress, I own it in 3 co...
# 10369        Love the dress. I feel it runs a tad small.
# 11619  The dress looks like the picture but the fabri...
# 19586  This dress was beautiful, but unfortunately it...
# 29098  I LOVE THESE SHIRTS. They are so comforable du...
# 29576  This is my new favorite shirt! Perfect over cu...
# 35763  This top is perfect for me: it's nice and room...
# 37635  I love these cardigans. They won't close for m...
# 38975  I LOVE THESE SHIRTS. They are so comforable du...
# 39588  I love these cardigans. They won't close for m...
# 41332  I LOVE THESE SHIRTS. They are so comforable du...
# 42130  I love these cardigans. They won't close for m...
# 44396  I really love this shirt. It was a little tigh...
# 47348                                   Must have shirt!
# 51383  I love these cardigans. They won't close for m...
# 53327  I really love these sweaters. I have a bunch i...
# 54090                                           Was okay
# 57726  I LOVE THESE SHIRTS. They are so comfortable d...
# 57727  I LOVE THESE SHIRTS. They are so comfortable d...
# 63119  The waist of this shirt was very tight, and I ...
# 64250  This skirt looks just like it does in the pict...
# 64697  I originally ordered a medium and exchanged it...
# 71407  The pattern is just as lovely in person, as in...
# 73583  These were soft and the color looked like the ...
# 75472  This dress has become a complete staple. It ha...
# 77423  These are great leggings to change up the norm...
# 80344  I need blazers to wear over some of my dresses...
# 80713  This jacket is lovely, but I couldn't move my ...

# %% [markdown]
# 6. Check for the category dress review and visualize the top 10 reviews using any relevant plot. Identify the negative reviews if there are any.

# %%
df4['review_summary'].value_counts().nlargest(10)
# Out:
# Love it!                     158
# I absolutely love this dr    118
# I really wanted to love t     84
# Love it                       82
# This is one of my favorit     79
# I love this dress so much     76
# .                             71
# I get so many compliments     67
# Perfect!                      63
# I love everything about t     57
# Name: review_summary, dtype: int64

# %%
df4['review_summary'].value_counts().nlargest(10).plot(kind='bar',color='brown')
plt.show()

# %% [markdown]
# There are no negative reviews in the review_summary column

# %% [markdown]
# 7. Find out the average shoe size for the different fits of the customer. Visualize using any relevant plot. Explain that, Is there any significant different shoe sizes for different fits?

# %%
df4.head(2)
# Out:
#       item_id  size  quality cup_size  hips  bra_size category  height  \
# 6725   152702     4      4.0        b  37.0      32.0      new     5.6
# 6726   152702     4      5.0        c  36.0      34.0      new     5.6
#
#      user_name          length    fit  user_id  shoe_size shoe_width  \
# 6725     avNYC      just right  small   668176        9.0    average
# 6726  lanwei91  slightly short    fit   320759        7.5    average
#
#            review_summary                                        review_text
# 6725     Too much ruching  I liked the color, the silhouette, and the fab...
# 6726  Suits my body type!  From the other reviews it seems like this dres...

# %%
df4.groupby('fit').mean()['shoe_size'].plot(kind='bar',color='green')
plt.show()

# %% [markdown]
# Therefore there is no significane in different shoe size for different fits.

# %% [markdown]
# 8. Identify the customer’s common shoe width and average size for those who purchased the maximum quality. Is the mode of shoe width affect the user review? Visualize using the appropriate plot.

# %%
df4.head(2)
# Out:
#       item_id  size  quality cup_size  hips  bra_size category  height  \
# 6725   152702     4      4.0        b  37.0      32.0      new     5.6
# 6726   152702     4      5.0        c  36.0      34.0      new     5.6
#
#      user_name          length    fit  user_id  shoe_size shoe_width  \
# 6725     avNYC      just right  small   668176        9.0    average
# 6726  lanwei91  slightly short    fit   320759        7.5    average
#
#            review_summary                                        review_text
# 6725     Too much ruching  I liked the color, the silhouette, and the fab...
# 6726  Suits my body type!  From the other reviews it seems like this dres...

# %%
df4['quality'].unique()
# Out:
# array([4., 5., 3., 2., 1.])

# %%
df4['shoe_width'].value_counts()  ### common shoe width is average
# Out:
# average    64545
# wide        3496
# narrow      1396
# Name: shoe_width, dtype: int64

# %%
print('Average size for those who purchased the maximum quality:', df4[df4['quality']==5.0].mean()['size'])
# Out:
# Average size for those who purchased the maximum quality: 12.289197766440365

# %% [markdown]
# 9. Extract the records belonging to the top 10 reviews, and then find the review summary for the different cup sizes. The basic analysis explains what you would try to infer. Try to use visualization.

# %%
df4['review_summary'].value_counts().nlargest(10)
# Out:
# Love it!                     158
# I absolutely love this dr    118
# I really wanted to love t     84
# Love it                       82
# This is one of my favorit     79
# I love this dress so much     76
# .                             71
# I get so many compliments     67
# Perfect!                      63
# I love everything about t     57
# Name: review_summary, dtype: int64

# %%
df4.groupby('cup_size').max()['review_summary']
# Out:
# cup_size
# a         you shouldn't have to spe
# aa         works perfectly with the
# b         zipper stuck a little, bu
# c         wow so much longer than I
# d         yup. This coat is amazing
# dd/e                             ye
# ddd/f                          yup.
# dddd/g    worst  fitting  top  ever
# h         when they say sleek, they
# i         very cute skirt, i love t
# j         this it by far the best t
# k         this shirt is actually ba
# Name: review_summary, dtype: object

# %%
df4['review_summary'].value_counts().head(10).plot(kind='bar')
plt.show()

# %% [markdown]
# 10. Identify the most common review that we got from the customer whose hips size is greater than 35. Find out what kind of inference you can make.

# %%
c= df4[df4['hips']>35]
c['review_summary'].value_counts().nlargest(1)
# Out:
# Love it!    133
# Name: review_summary, dtype: int64

# %% [markdown]
# The inference we can make is that even the customers whose hip size is greater than 35 are fully satisfied with the product.

# %% [markdown]
# 11. What is the relationship between height and weight? Describe what kind of relationship it has.

# %%
sns.boxplot(df4['shoe_width'],df4['height'])
plt.show() 
### There is no weight column in the data so the question is inadequate to solve.

# %% [markdown]
# 12. Plot the pair plot for the numerical plot. Explain according to your problem statement how the pair plot would help you.\

# %%
sns.pairplot(df4)
plt.show()

# %% [markdown]
# # Statistical Analysis:

# %% [markdown]
# 1. Test the claim that the category feature and review summary have any relationship among them. The level of significance is 5%.

# %% [raw]
# H0=There is no relationship between review summary and category
# H1=There is relaton between review summary and category

# %%
stats.chi2_contingency(pd.crosstab(df4['category'],df4['review_summary']))
# Out:
# (358635.3297362131,
#  2.209010006486122e-107,
#  340182,
#  array([[0.38518369, 0.19259185, 0.19259185, ..., 0.19259185, 0.19259185,
#          0.19259185],
#         [0.49575875, 0.24787937, 0.24787937, ..., 0.24787937, 0.24787937,
#          0.24787937],
#         [0.3918372 , 0.1959186 , 0.1959186 , ..., 0.1959186 , 0.1959186 ,
#          0.1959186 ],
#         ...,
#         [0.06307876, 0.03153938, 0.03153938, ..., 0.03153938, 0.03153938,
#          0.03153938],
#         [0.54406152, 0.27203076, 0.27203076, ..., 0.27203076, 0.27203076,
#          0.27203076],
#         [0.00697035, 0.00348517, 0.00348517, ..., 0.00348517, 0.00348517,
#          0.00348517]]))

# %% [markdown]
# Since p _value is <0.05 so we reject null hypothesis.Therefore,there is relaton between review summary and category

# %% [markdown]
# 2. Test statistically whether the size and hips have any relationship using 0.05 alpha. Before the above test, Test the normality test.

# %%
df4.head(2)
# Out:
#       item_id  size  quality cup_size  hips  bra_size category  height  \
# 6725   152702     4      4.0        b  37.0      32.0      new     5.6
# 6726   152702     4      5.0        c  36.0      34.0      new     5.6
#
#      user_name          length    fit  user_id  shoe_size shoe_width  \
# 6725     avNYC      just right  small   668176        9.0    average
# 6726  lanwei91  slightly short    fit   320759        7.5    average
#
#            review_summary                                        review_text
# 6725     Too much ruching  I liked the color, the silhouette, and the fab...
# 6726  Suits my body type!  From the other reviews it seems like this dres...

# %%
# For the normality test we use the Wilks Shpairo test
stat, p_value = stats.shapiro(df4['hips'])
print('p_value',p_value)
# Out:
# p_value 0.0

# %% [markdown]
# Since the pvalue is less than 0.05 we reject H0 and conclude that the hips data is not normal.

# %%
stat, p_value = stats.shapiro(df4['size'])
print('p_value',p_value)
# Out:
# p_value 0.0

# %% [markdown]
# Since the pvalue is less than 0.05 we reject H0 and conclude that the size data is not normal.

# %% [raw]
# H0=size and hips are not related to each other
# H1=size and hips are related to each other

# %%
df4['hips'].unique()
# Out:
# array([37., 36., 39., 35., 32., 40., 38., 41., 34., 42., 45., 43., 44.,
#        33., 50., 30., 48., 46., 47., 49., 60., 59., 53., 56., 52., 51.,
#        55., 54., 31., 58., 57.])

# %%
df4['size'].unique()
# Out:
# array([ 4,  8, 12, 32, 26, 20, 15, 38,  1, 11,  3, 24, 21, 30, 18,  5,  9,
#         7, 13, 33, 27,  0,  6, 31, 10, 14, 17,  2], dtype=int64)

# %%
# Correlation
df4['hips'].corr(df4['size'])
# Out:
# 0.6150259455542333

# %%
stats.ttest_ind(df4['hips'],df4['size'])
# Out:
# Ttest_indResult(statistic=755.3543878331607, pvalue=0.0)

# %% [markdown]
# Since p value is less than 0.05 we reject H0. Therefore size and hips are related to each other.

# %% [markdown]
# 3. Does the quality significantly differ for any one shoe width? Test the test with 96% confidence intervals.Check the normality of the data before the above test. Alpha = 0.4

# %%
# Normality test
stats.shapiro(df4['quality'])
# The data is not normal
# Out:
# ShapiroResult(statistic=0.8489657044410706, pvalue=0.0)

# %% [raw]
# H0:Quality does not significantly differ for any one shoe width
# H1:Quality does significantly differ for any one shoe width

# %%
pd.crosstab(df4['quality'],df4['shoe_width'])
# Out:
# shoe_width  average  narrow  wide
# quality
# 1.0            1016      23    67
# 2.0            3967      83   219
# 3.0           15274     305   822
# 4.0           21210     442  1116
# 5.0           23078     543  1272

# %%
stats.chi2_contingency(pd.crosstab(df4['quality'],df4['shoe_width']))
# Out:
# (10.063355968731056,
#  0.2606072956154113,
#  8,
#  array([[1.02807970e+03, 2.22356381e+01, 5.56846638e+01],
#         [3.96823891e+03, 8.58263462e+01, 2.14934747e+02],
#         [1.52455110e+04, 3.29734810e+02, 8.25754223e+02],
#         [2.11639408e+04, 4.57740513e+02, 1.14631865e+03],
#         [2.31392296e+04, 5.00462693e+02, 1.25330772e+03]]))

# %% [markdown]
# Since the pvalue is greater than 0.04,we fail to reject null hypothesis. Therefore quality does not significantly differ for any one shoe width.

# %% [markdown]
# 4. Check if the shoe width feature affects the review summary with a 99% confidence interval.

# %% [raw]
# H0:Shoe width feature does not affect the review summary
# H1:Shoe width feature affect the review summary.

# %%
pd.crosstab(df4['shoe_width'],df4['review_summary'])
# Out:
# review_summary  !  !!!  !!!!  #4 for me! I'm collecting  \
# shoe_width
# average         2    1     1                          1
# narrow          0    0     0                          0
# wide            0    0     0                          0
#
# review_summary  #FashionDeux  This is the  #FashionDeux I have been  \
# shoe_width
# average                                 1                         1
# narrow                                  0                         0
# wide                                    0                         0
#
# review_summary  #FashionDeux This skirt i  #Review ContestAlthough t  \
# shoe_width
# average                                 1                          1
# narrow                                  0                          0
# wide                                    0                          0
#
# review_summary  #ReviewContest  #ReviewContest    I don't  ...  \
# shoe_width                                                 ...
# average                      1                          1  ...
# narrow                       0                          0  ...
# wide                         0                          0  ...
#
# review_summary  you could probably size d  you get what you pay for  \
# shoe_width
# average                                 0                         1
# narrow                                  1                         0
# wide                                    0                         0
#
# review_summary  you have it in other colo  you know who this dress d  \
# shoe_width
# average                                 1                          1
# narrow                                  0                          0
# wide                                    0                          0
#
# review_summary  you need every color  you should buy every colo  \
# shoe_width
# average                            1                          1
# narrow                             0                          0
# wide                               0                          0
#
# review_summary  you shouldn't have to spe  yup.  yup. This coat is amazing  \
# shoe_width
# average                                 1     1                          1
# narrow                                  0     0                          0
# wide                                    0     0                          0
#
# review_summary  zipper stuck a little, bu
# shoe_width
# average                                 1
# narrow                                  0
# wide                                    0
#
# [3 rows x 56698 columns]

# %%
stats.chi2_contingency(pd.crosstab(df4['shoe_width'],df4['review_summary']))
# Out:
# (117646.78700064366,
#  5.602406145393808e-19,
#  113394,
#  array([[1.8590953 , 0.92954765, 0.92954765, ..., 0.92954765, 0.92954765,
#          0.92954765],
#         [0.04020911, 0.02010456, 0.02010456, ..., 0.02010456, 0.02010456,
#          0.02010456],
#         [0.10069559, 0.0503478 , 0.0503478 , ..., 0.0503478 , 0.0503478 ,
#          0.0503478 ]]))

# %% [markdown]
# Since the pvalue is less than 0.01 we reject the Null Hyothesis therefore we conclude that shoe width feature does affect the review summary.

# %% [markdown]
# 5. Check if the length feature affects the review summary with a 95% confidence interval.

# %% [raw]
# H0:Length feature does not affect the review summary.
# H1:Length feature does affect the review summary.

# %%
pd.crosstab(df4['length'],df4['review_summary'])
# Out:
# review_summary  !  !!!  !!!!  #4 for me! I'm collecting  \
# length
# just right      1    1     1                          1
# slightly long   1    0     0                          0
# slightly short  0    0     0                          0
# very long       0    0     0                          0
# very short      0    0     0                          0
#
# review_summary  #FashionDeux  This is the  #FashionDeux I have been  \
# length
# just right                              0                         1
# slightly long                           1                         0
# slightly short                          0                         0
# very long                               0                         0
# very short                              0                         0
#
# review_summary  #FashionDeux This skirt i  #Review ContestAlthough t  \
# length
# just right                              1                          0
# slightly long                           0                          0
# slightly short                          0                          0
# very long                               0                          1
# very short                              0                          0
#
# review_summary  #ReviewContest  #ReviewContest    I don't  ...  \
# length                                                     ...
# just right                   1                          1  ...
# slightly long                0                          0  ...
# slightly short               0                          0  ...
# very long                    0                          0  ...
# very short                   0                          0  ...
#
# review_summary  you could probably size d  you get what you pay for  \
# length
# just right                              0                         1
# slightly long                           0                         0
# slightly short                          0                         0
# very long                               1                         0
# very short                              0                         0
#
# review_summary  you have it in other colo  you know who this dress d  \
# length
# just right                              1                          1
# slightly long                           0                          0
# slightly short                          0                          0
# very long                               0                          0
# very short                              0                          0
#
# review_summary  you need every color  you should buy every colo  \
# length
# just right                         1                          1
# slightly long                      0                          0
# slightly short                     0                          0
# very long                          0                          0
# very short                         0                          0
#
# review_summary  you shouldn't have to spe  yup.  yup. This coat is amazing  \
# length
# just right                              1     1                          1
# slightly long                           0     0                          0
# slightly short                          0     0                          0
# very long                               0     0                          0
# very short                              0     0                          0
#
# review_summary  zipper stuck a little, bu
# length
# just right                              1
# slightly long                           0
# slightly short                          0
# very long                               0
# very short                              0
#
# [5 rows x 56698 columns]

# %%
stats.chi2_contingency(pd.crosstab(df4['length'],df4['review_summary']))
# Out:
# (241498.85586971516,
#  8.488593378558512e-102,
#  226788,
#  array([[1.49133747, 0.74566874, 0.74566874, ..., 0.74566874, 0.74566874,
#          0.74566874],
#         [0.27818022, 0.13909011, 0.13909011, ..., 0.13909011, 0.13909011,
#          0.13909011],
#         [0.1511298 , 0.0755649 , 0.0755649 , ..., 0.0755649 , 0.0755649 ,
#          0.0755649 ],
#         [0.0606305 , 0.03031525, 0.03031525, ..., 0.03031525, 0.03031525,
#          0.03031525],
#         [0.01872201, 0.009361  , 0.009361  , ..., 0.009361  , 0.009361  ,
#          0.009361  ]]))

# %% [markdown]
# Since the pvalue is less than 0.05 we reject the Null Hyothesis therefore we conclude that length feature does affect the review summary.

# %% [markdown]
# 6. Does the average quality significantly differ for the different fits? Kindly test the relevant hypothesis test by having 0.05 alpha. Check the normality of the data before the above test. Alpha = .05

# %%
#Normality test
stats.shapiro(df4['quality'])
# The data is not normal
# Out:
# ShapiroResult(statistic=0.8489657044410706, pvalue=0.0)

# %% [raw]
# H0:Average quality does not significantly differ for the different fits
# H1:Average quality significantly differ for the different fits

# %%
df4['fit'].unique()
# Out:
# array(['small', 'fit', 'large'], dtype=object)

# %%
small=df4[df4['fit']=='small']['quality']
fit=df4[df4['fit']=='fit']['quality']
large=df4[df4['fit']=='large']['quality']

# %%
stats.f_oneway(small,fit,large)
# Out:
# F_onewayResult(statistic=1788.0622798019433, pvalue=0.0)

# %% [markdown]
# Since the pvalue is less than 0.05 we reject H0. Therefore we can conclude that average quality significantly differ for the different fits.
